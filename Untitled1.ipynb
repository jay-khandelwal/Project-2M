# %%
import pandas as pd

# %%
df = pd.read_json('data.json')
df['Referer'] = df['Referer'].fillna("None")

df["full_path"] = "https://"+df['Host']+df['path']

# %%
df
# Out:
#                        Origin  \
# 0    https://www.evernote.com
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 193                       NaN
# 194  https://www.evernote.com
# 195  https://www.evernote.com
# 196  https://www.evernote.com
# 197                       NaN
#
#                                             User-Agent Sec-Fetch-Dest  \
# 0    Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; ...          empty
# 1    Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; ...          style
# 2    Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; ...         script
# 3    Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; ...         script
# 4    Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; ...         script
# ..                                                 ...            ...
# 193  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; ...          image
# ...

# %%
df[df[[]].to_csv('miro-s.csv', index=False)

# %%
df[['Referer', 'full_path']].to_csv('miro-s.csv', index=False)
